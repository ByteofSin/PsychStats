# %%
# !python -m venv venv

# %%
# !pip install matplotlib
# !pip install numpy
# !pip install pandas
# !pip install pyspssio
# !pip install scikit-learn
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import pyspssio
from importlib import reload

# %%
import metrics
import visualization

reload(metrics)
reload(visualization)
# Out:
# <module 'visualization' from 'c:\\Users\\ajcyrw\\PsychStats\\visualization.py'>

# %%
data_directory = "./data/fish data.sav"

# %%
df, meta = pyspssio.read_sav(data_directory)

# %%
df.dtypes
# Out:
# Species         str
# Weight      float64
# Vertical    float64
# Diagonal    float64
# Cross       float64
# Height      float64
# Width       float64
# dtype: object

# %%
df
# Out:
#     Species  Weight  Vertical  Diagonal  Cross   Height   Width
# 0     Bream   242.0      23.2      25.4   30.0  11.5200  4.0200
# 1     Bream   290.0      24.0      26.3   31.2  12.4800  4.3056
# 2     Bream   340.0      23.9      26.5   31.1  12.3778  4.6961
# 3     Bream   363.0      26.3      29.0   33.5  12.7300  4.4555
# 4     Bream   430.0      26.5      29.0   34.0  12.4440  5.1340
# ..      ...     ...       ...       ...    ...      ...     ...
# 154   Smelt    12.2      11.5      12.2   13.4   2.0904  1.3936
# 155   Smelt    13.4      11.7      12.4   13.5   2.4300  1.2690
# 156   Smelt    12.2      12.1      13.0   13.8   2.2770  1.2558
# 157   Smelt    19.7      13.2      14.3   15.2   2.8728  2.0672
# 158   Smelt    19.9      13.8      15.0   16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
df[df.dtypes[df.dtypes == "float64"].index]
# Out:
#      Weight  Vertical  Diagonal  Cross   Height   Width
# 0     242.0      23.2      25.4   30.0  11.5200  4.0200
# 1     290.0      24.0      26.3   31.2  12.4800  4.3056
# 2     340.0      23.9      26.5   31.1  12.3778  4.6961
# 3     363.0      26.3      29.0   33.5  12.7300  4.4555
# 4     430.0      26.5      29.0   34.0  12.4440  5.1340
# ..      ...       ...       ...    ...      ...     ...
# 154    12.2      11.5      12.2   13.4   2.0904  1.3936
# 155    13.4      11.7      12.4   13.5   2.4300  1.2690
# 156    12.2      12.1      13.0   13.8   2.2770  1.2558
# 157    19.7      13.2      14.3   15.2   2.8728  2.0672
# 158    19.9      13.8      15.0   16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
visualization.correlation_matrix(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 visualization.correlation_matrix(df)
#
# File ~\PsychStats\visualization.py:39, in correlation_matrix(data)
#      38 def correlation_matrix(data):
# ---> 39     corr = data.corr()
#      40     sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
#      41     plt.title("Correlation Matrix")
#
# File ~\PsychStats\venv\Lib\site-packages\pandas\core\frame.py:13135, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13131         """  # noqa: E501
#   13132         data = self._get_numeric_data() if numeric_only else self
#   13133         cols = data.columns
#   13134         idx = cols.copy()
# > 13135         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13136
#   13137         if method == "pearson":
# ...

# %%
df[df.dtypes[df.dtypes == "float64"].index].corr()
# Out:
#             Weight  Vertical  Diagonal     Cross    Height     Width
# Weight    1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Vertical  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Diagonal  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Cross     0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height    0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width     0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
xlabel="Age"
ylabel="WeightLOST"

# %%
visualization.scatter_plot(
    df,  
    xlabel=xlabel,
    ylabel=ylabel)

# %%
visualization.histogram(
    df,
    bins=10,
    key="WeightLOST"
)

# %%
reload(metrics)
# Out:
# <module 'metrics' from 'c:\\Users\\ajcyrw\\PsychStats\\metrics.py'>

# %%
metrics.mean(df, "WeightLOST")
# Out:
# 3.8448717948717945

# %%
metrics.variance(df, "WeightLOST")
# Out:
# 6.5100382950382905

# %%
metrics.stddev(df, "WeightLOST")
# Out:
# 2.5514776689280056

# %%
metrics.zscore(df, 4, "WeightLOST")
# Out:
# 0.06079935835510645

# %%
metrics.skewness(df, "WeightLOST")
# Out:
# 0.05247096064234722

# %%
metrics.kurtosis(df, "WeightLOST")
# Out:
# -0.45018729490845466

# %%
zScores = pd.read_csv("table/math-z-score-table_EN.csv")

# %%
zScores
# Out:
#      Z-Score  Cumulative Probability P(Z≤z)  Right Tail P(Z>z)  \
# 0       0.00                         0.5000             0.5000
# 1       0.01                         0.5040             0.4960
# 2       0.02                         0.5080             0.4920
# 3       0.03                         0.5120             0.4880
# 4       0.04                         0.5160             0.4840
# ..       ...                            ...                ...
# 305     3.50                         0.9998             0.0002
# 306     3.60                         0.9998             0.0002
# 307     3.70                         0.9999             0.0001
# 308     3.80                         0.9999             0.0001
# 309     3.90                         1.0000             0.0000
#
#      Percentile (%) Two-Tail Confidence
# 0             50.00                   -
# 1             50.40                0.8%
# 2             50.80                1.6%
# 3             51.20                2.4%
# ...

# %%
zScores[zScores["Z-Score"] == 1.96]["Percentile (%)"].values[0]/100
# Out:
# np.float64(0.975)
