# %%
# !python -m venv venv

# %%
# !pip install matplotlib
# !pip install numpy
# !pip install pandas
# !pip install pyspssio
# Out:
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------  9.2/9.3 MB 49.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 35.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 36.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------  12.3/12.6 MB 60.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 41.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 7.2/7.2 MB 40.5 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
# ...

# %%
import pandas as pd
import numpy as np

import pyspssio
from importlib import reload

# %%
import metrics
import visualization

reload(metrics)
reload(visualization)
# Out:
# <module 'visualization' from 'c:\\Users\\ajcyrw\\PsychStats\\visualization.py'>

# %%
data_directory = "./data/SPSS Descriptives-1.sav"

# %%
df, meta = pyspssio.read_sav(data_directory)

# %%
df.dtypes
# Out:
# Person           float64
# Gender           float64
# Age              float64
# Height           float64
# Preweight        float64
# Diet             float64
# Weight10weeks    float64
# WeightLOST       float64
# dtype: object

# %%
df
# Out:
#     Person  Gender   Age  Height  Preweight  Diet  Weight10weeks  WeightLOST
# 0     25.0   -99.0  41.0   171.0       60.0   2.0           60.0         0.0
# 1     26.0   -99.0  32.0   174.0      103.0   2.0          103.0         0.0
# 2      1.0     0.0  22.0   159.0       58.0   1.0           54.2         3.8
# 3      2.0     0.0  46.0   192.0       60.0   1.0           54.0         6.0
# 4      3.0     0.0  55.0   170.0       64.0   1.0           63.3         0.7
# ..     ...     ...   ...     ...        ...   ...            ...         ...
# 73    74.0     1.0  35.0   183.0       83.0   3.0           80.2         2.8
# 74    75.0     1.0  49.0   177.0       84.0   3.0           79.9         4.1
# 75    76.0     1.0  28.0   164.0       85.0   3.0           79.7         5.3
# 76    77.0     1.0  40.0   167.0       87.0   3.0           77.8         9.2
# 77    78.0     1.0  51.0   175.0       88.0   3.0           81.9         6.1
#
# [78 rows x 8 columns]

# %%
xlabel="Age"
ylabel="WeightLOST"

# %%
visualization.scatter_plot(
    df,  
    xlabel=xlabel,
    ylabel=ylabel)

# %%
visualization.histogram(
    df,
    bins=10,
    "WeightLOST"
)
